# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import re

# %%
SLvAUS = [x.lower() for x in['#SLvAUS', '#SLvsAUS', '#OfficialSLC', '#RoaringForGlory', '#ApeKollo', '#SriLankanCricketTeam', '#TeamSriLanka',
        '#SriLankanTeam', '#SrilankaCricket', '#GemmakThamai', '@OfficialSLC']]
INDvSA = [x.lower() for x in['#INDvSA', '#INDvsSA', '#INDvRSA', '#INDvsRSA', '#TeamIndia', '#BCCI', '#IndianCricket', '#IndianCricketTeam', 
          '#bharatarmy', '#MenInBlue', '@BCCI', '@Bharatharmy']]
SAvIND = [x.lower() for x in['#SAvIND', '#SAvsIND', '#RSAvIND', '#RSAvsIND', '#ProteaFire', '#Proteas', '#CricketSouthAfrica', 
          '#rsacricket', '#sacricket', '#SouthAfricanCricket', '@ProteasMenCSA' ]]
AUSvENG = [x.lower() for x in['#AUSvENG', '#AUSvsENG', '#australiancricket', '#CricketAustralia', '#australiacricket', 
         '#CricketAus', '#cricketcomau', '@cricketcomau', '@CricketAus'  ]]
ENGvAUS = [x.lower() for x in['#ENGvAUS', '#ENGvsAUS', '#englandcricket', '#englandteam', '#EnglandCricketTeam', 
         '#cricketengland', '#TheBarmyArmy', '@englandcricket', '@TheBarmyArmy'  ]]
PAKvWI = [x.lower() for x in['#PAKvWI', '#PAKvsWI', '#BackTheBoysInGreen', '#TheGreenArmy', '#packistancricket', 
         '#packistancricketteam', '#TheRealPCB', '#PakCricket', '#cricketpakistan', '@TheRealPCB' ]]
WIvPAK = [x.lower() for x in['#WIvPAK', '#WIvsPAK', '#MenInMaroon', '#WestIndies', '#Windies', 
         '#windiescricket', '#westindiescricket', '@windiescricket'  ]]
INDvWI = [x.lower() for x in['#INDvWI', '#INDvsWI', '#TeamIndia', '#BCCI', '#IndianCricket', '#IndianCricketTeam', 
          '#bharatarmy', '#MenInBlue', '@BCCI', '@Bharatharmy']]
WIvIND = [x.lower() for x in['#WIvIND', '#WIvsIND', '#MenInMaroon', '#WestIndies', '#Windies', 
         '#windiescricket', '#westindiescricket', '@windiescricket'  ]]
SLvENG = [x.lower() for x in['#SLvENG', '#SLvsENG', '#OfficialSLC', '#RoaringForGlory', '#ApeKollo', '#SriLankanCricketTeam', '#TeamSriLanka',
        '#SriLankanTeam', '#SrilankaCricket', '#GemmakThamai', '@OfficialSLC']]
ENGvSL = [x.lower() for x in['#ENGvSL', '#ENGvsSL', '#englandcricket', '#englandteam', '#EnglandCricketTeam', 
         '#cricketengland', '#TheBarmyArmy', '@englandcricket', '@TheBarmyArmy'  ]]
SLvAUS = [x.lower() for x in['#SLvAUS', '#SLvsAUS', '#OfficialSLC', '#RoaringForGlory', '#ApeKollo', '#SriLankanCricketTeam', '#TeamSriLanka',
        '#SriLankanTeam', '#SrilankaCricket', '#GemmakThamai', '@OfficialSLC']]
AUSvSL = [x.lower() for x in['#AUSvSL', '#AUSvsSL', '#australiancricket', '#CricketAustralia', '#australiacricket', 
         '#CricketAus', '#cricketcomau', '@cricketcomau', '@CricketAus'  ]]
INDvENG = [x.lower() for x in['#INDvENG', '#INDvsENG', '#TeamIndia', '#BCCI', '#IndianCricket', '#IndianCricketTeam', 
          '#bharatarmy', '#MenInBlue', '@BCCI', '@Bharatharmy']]
ENGvIND = [x.lower() for x in['#ENGvIND', '#ENGvsIND', '#englandcricket', '#englandteam', '#EnglandCricketTeam', 
         '#cricketengland', '#TheBarmyArmy', '@englandcricket', '@TheBarmyArmy'  ]]
ENGvWI = [x.lower() for x in['#ENGvWI', '#ENGvsWI', '#englandcricket', '#englandteam', '#EnglandCricketTeam', 
         '#cricketengland', '#TheBarmyArmy', '@englandcricket', '@TheBarmyArmy'  ]]
WIvENG = [x.lower() for x in['#WIvENG', '#WIvsENG', '#MenInMaroon', '#WestIndies', '#Windies', 
         '#windiescricket', '#westindiescricket', '@windiescricket'  ]]
BANvWI = [x.lower() for x in['#BANvWI', '#BANvsWI', '#RiseOfTheTigers', '#BCBtigers', '#BangladeshCricket', 
         '#bangladeshcricketteam', '#bdcricket', '#bdtigers', '#bdcricket_team', '@BCBtigers'  ]]
WIvBAN = [x.lower() for x in['#WIvBAN', '#WIvsBAN', '#MenInMaroon', '#WestIndies', '#Windies', 
         '#windiescricket', '#westindiescricket', '@windiescricket'  ]]
AUSvSA = [x.lower() for x in['#AUSvSA', '#AUSvsSA', '#AUSvRSA', '#AUSvsRSA', '#australiancricket', '#CricketAustralia', '#australiacricket', 
         '#CricketAus', '#cricketcomau', '@cricketcomau', '@CricketAus'  ]]
SAvAUS = [x.lower() for x in['#SAvAUS', '#SAvsAUS', '#RSAvAUS', '#RSAvsAUS', '#ProteaFire', '#Proteas', '#CricketSouthAfrica', 
          '#rsacricket', '#sacricket', '#SouthAfricanCricket', '@ProteasMenCSA' ]]
SLvPAK = [x.lower() for x in['#SLvPAK', '#SLvsPAK', '#OfficialSLC', '#RoaringForGlory', '#ApeKollo', '#SriLankanCricketTeam', '#TeamSriLanka',
        '#SriLankanTeam', '#SrilankaCricket', '#GemmakThamai', '@OfficialSLC']]
PAKvSL = [x.lower() for x in['#PAKvSL', '#PAKvsSL', '#BackTheBoysInGreen', '#TheGreenArmy', '#packistancricket', 
         '#packistancricketteam', '#TheRealPCB', '#PakCricket', '#cricketpakistan', '@TheRealPCB' ]]
PAKvBAN = [x.lower() for x in['#PAKvBAN', '#PAKvsBAN', '#BackTheBoysInGreen', '#TheGreenArmy', '#packistancricket', 
         '#packistancricketteam', '#TheRealPCB', '#PakCricket', '#cricketpakistan', '@TheRealPCB' ]]
BANvPAK = [x.lower() for x in['#BANvPAK', '#BANvsPAK', '#RiseOfTheTigers', '#BCBtigers', '#BangladeshCricket', 
         '#bangladeshcricketteam', '#bdcricket', '#bdtigers', '#bdcricket_team', '@BCBtigers'  ]]
INDvAUS = [x.lower() for x in['#INDvAUS', '#INDvsAUS', '#TeamIndia', '#BCCI', '#IndianCricket', '#IndianCricketTeam', 
          '#bharatarmy', '#MenInBlue', '@BCCI', '@Bharatharmy']]
AUSvIND = [x.lower() for x in['#AUSvIND', '#AUSvsIND', '#australiancricket', '#CricketAustralia', '#australiacricket', 
         '#CricketAus', '#cricketcomau', '@cricketcomau', '@CricketAus'  ]]
SAvNZ =  [x.lower() for x in['#SAvNZ', '#SAvsNZ', '#RSAvNZ', '#RSAvsNZ', '#ProteaFire', '#Proteas', '#CricketSouthAfrica', 
          '#rsacricket', '#sacricket', '#SouthAfricanCricket', '@ProteasMenCSA' ]]
NZvSA =  [x.lower() for x in['NZvSA', '#NZvsSA', '#NZvRSA', '#NZvsRSA', '#BACKTHEBLACKCAPS', '#blackcaps', '#NZC', 
          '#newzealandcricket', '#nzcricket',   '@BLACKCAPS' ]]
ENGvPAK = [x.lower() for x in['#ENGvPAK', '#ENGvsPAK', '#englandcricket', '#englandteam', '#EnglandCricketTeam', 
         '#cricketengland', '#TheBarmyArmy', '@englandcricket', '@TheBarmyArmy'  ]]
PAKvENG = [x.lower() for x in['#PAKvENG', '#PAKvsENG', '#BackTheBoysInGreen', '#TheGreenArmy', '#packistancricket', 
         '#packistancricketteam', '#TheRealPCB', '#PakCricket', '#cricketpakistan', '@TheRealPCB' ]]
AUSvWI = [x.lower() for x in['#AUSvWI', '#AUSvsWI', '#australiancricket', '#CricketAustralia', '#australiacricket', 
         '#CricketAus', '#cricketcomau', '@cricketcomau', '@CricketAus'  ]]
WIvAUS = [x.lower() for x in['#WIvAUS', '#WIvsAUS', '#MenInMaroon', '#WestIndies', '#Windies', 
         '#windiescricket', '#westindiescricket', '@windiescricket'  ]]
NZvWI = [x.lower() for x in['NZvWI', '#NZvsWI', '#BACKTHEBLACKCAPS', '#blackcaps', '#NZC', 
          '#newzealandcricket', '#nzcricket',   '@BLACKCAPS' ]]
WIvNZ = [x.lower() for x in['#WIvNZ', '#WIvsNZ', '#MenInMaroon', '#WestIndies', '#Windies', 
         '#windiescricket', '#westindiescricket', '@windiescricket'  ]]
INDvSL = [x.lower() for x in['#INDvSL', '#INDvsSL', '#TeamIndia', '#BCCI', '#IndianCricket', '#IndianCricketTeam', 
          '#bharatarmy', '#MenInBlue', '@BCCI', '@Bharatharmy']]
SLvIND = [x.lower() for x in['#SLvIND', '#SLvsIND', '#OfficialSLC', '#RoaringForGlory', '#ApeKollo', '#SriLankanCricketTeam', '#TeamSriLanka',
        '#SriLankanTeam', '#SrilankaCricket', '#GemmakThamai', '@OfficialSLC']]
AUSvPAK = [x.lower() for x in['#AUSvPAK', '#AUSvsPAK', '#australiancricket', '#CricketAustralia', '#australiacricket', 
         '#CricketAus', '#cricketcomau', '@cricketcomau', '@CricketAus'  ]]
PAKvAUS = [x.lower() for x in['#PAKvAUS', '#PAKvsAUS', '#BackTheBoysInGreen', '#TheGreenArmy', '#packistancricket', 
         '#packistancricketteam', '#TheRealPCB', '#PakCricket', '#cricketpakistan', '@TheRealPCB' ]]
ENGvSA = [x.lower() for x in['#ENGvSA', '#ENGvsSA', '#ENGvRSA', '#ENGvsRSA', '#englandcricket', '#englandteam', '#EnglandCricketTeam', 
         '#cricketengland', '#TheBarmyArmy', '@englandcricket', '@TheBarmyArmy'  ]]
SAvENG = [x.lower() for x in['#SAvENG', '#SAvsENG', '#RSAvENG', '#RSAvsENG', '#ProteaFire', '#Proteas', '#CricketSouthAfrica', 
          '#rsacricket', '#sacricket', '#SouthAfricanCricket', '@ProteasMenCSA' ]]
INDvNZ = [x.lower() for x in['#INDvNZ', '#INDvsNZ', '#TeamIndia', '#BCCI', '#IndianCricket', '#IndianCricketTeam', 
          '#bharatarmy', '#MenInBlue', '@BCCI', '@Bharatharmy']]
NZvIND = [x.lower() for x in['NZvIND', '#NZvsIND', '#BACKTHEBLACKCAPS', '#blackcaps', '#NZC', 
          '#newzealandcricket', '#nzcricket',   '@BLACKCAPS' ]]
NZvBAN = [x.lower() for x in['NZvBAN', '#NZvsBAN', '#BACKTHEBLACKCAPS', '#blackcaps', '#NZC', 
          '#newzealandcricket', '#nzcricket',   '@BLACKCAPS' ]]
BANvNZ = [x.lower() for x in['#BANvNZ', '#BANvsNZ', '#RiseOfTheTigers', '#BCBtigers', '#BangladeshCricket', 
         '#bangladeshcricketteam', '#bdcricket', '#bdtigers', '#bdcricket_team', '@BCBtigers'  ]]
SLvSA = [x.lower() for x in['#SLvSA', '#SLvsSA', '#SLvRSA', '#SLvsRSA', '#OfficialSLC', '#RoaringForGlory', '#ApeKollo', '#SriLankanCricketTeam', '#TeamSriLanka',
        '#SriLankanTeam', '#SrilankaCricket', '#GemmakThamai', '@OfficialSLC']]
SAvSL = [x.lower() for x in['#SAvSL', '#SAvsSL', '#RSAvSL', '#RSAvsSL', '#ProteaFire', '#Proteas', '#CricketSouthAfrica', 
          '#rsacricket', '#sacricket', '#SouthAfricanCricket', '@ProteasMenCSA' ]]
PAKvNZ = [x.lower() for x in['#PAKvNZ', '#PAKvsNZ', '#BackTheBoysInGreen', '#TheGreenArmy', '#packistancricket', 
         '#packistancricketteam', '#TheRealPCB', '#PakCricket', '#cricketpakistan', '@TheRealPCB' ]]
NZvPAK = [x.lower() for x in['NZvPAK', '#NZvsPAK', '#BACKTHEBLACKCAPS', '#blackcaps', '#NZC', 
          '#newzealandcricket', '#nzcricket',   '@BLACKCAPS' ]]
PAKvSA = [x.lower() for x in['#PAKvSA', '#PAKvsSA', '#PAKvRSA', '#PAKvsRSA', '#BackTheBoysInGreen', '#TheGreenArmy', '#packistancricket', 
         '#packistancricketteam', '#TheRealPCB', '#PakCricket', '#cricketpakistan', '@TheRealPCB' ]]
SAvPAK = [x.lower() for x in['#SAvPAK', '#SAvsPAK', '#RSAvPAK', '#RSAvsPAK', '#ProteaFire', '#Proteas', '#CricketSouthAfrica', 
          '#rsacricket', '#sacricket', '#SouthAfricanCricket', '@ProteasMenCSA' ]]
ENGvNZ = [x.lower() for x in['#ENGvNZ', '#ENGvsNZ', '#englandcricket', '#englandteam', '#EnglandCricketTeam', 
         '#cricketengland', '#TheBarmyArmy', '@englandcricket', '@TheBarmyArmy'  ]]
NZvENG = [x.lower() for x in['NZvENG', '#NZvsENG', '#BACKTHEBLACKCAPS', '#blackcaps', '#NZC', 
          '#newzealandcricket', '#nzcricket',   '@BLACKCAPS' ]]
SLvWI = [x.lower() for x in['#SLvWI', '#SLvsWI', '#OfficialSLC', '#RoaringForGlory', '#ApeKollo', '#SriLankanCricketTeam', '#TeamSriLanka',
        '#SriLankanTeam', '#SrilankaCricket', '#GemmakThamai', '@OfficialSLC']]
WIvSL = [x.lower() for x in['#WIvSL', '#WIvsSL', '#MenInMaroon', '#WestIndies', '#Windies', 
         '#windiescricket', '#westindiescricket', '@windiescricket'  ]]
INDvPAK = [x.lower() for x in['#INDvPAK', '#INDvsPAK', '#TeamIndia', '#BCCI', '#IndianCricket', '#IndianCricketTeam', 
          '#bharatarmy', '#MenInBlue', '@BCCI', '@Bharatharmy']]
PAKvIND = [x.lower() for x in['#PAKvIND', '#PAKvsIND', '#BackTheBoysInGreen', '#TheGreenArmy', '#packistancricket', 
         '#packistancricketteam', '#TheRealPCB', '#PakCricket', '#cricketpakistan', '@TheRealPCB' ]]

# %%
# remove tweets contain question words
def has_a_question(tweet):
    # a regular expression pattern to identify question mark
    pattern1 = r'\?'
    # a regular expression pattern to identify any question word
    pattern2 = r"\b(who|what|when|where|why|how)\b" 
    # Combine the two patterns using the OR (|) operator
    pattern = r'({}|{})'.format(pattern1, pattern2)
    # search function to find tweets with question 
    q_tweet = re.search(pattern , tweet, re.IGNORECASE)
    # Return True if the tweet has a question
    return q_tweet is not None

# select tweets with particualr hashtag & handle 1st
def select_tweet_with_item(tweets, list1):
    selected_tweets = []
    for tweet in tweets:
        for item in list1:
            if item in tweet:
                # Use a regular expression to find all hashtags & handles mentioned in the tweet
                hashtags = re.findall(r"#\w+", tweet)
                handles = re.findall(r"@\w+", tweet)
                # Check if the specified hashtag or handle appears before any other hashtags or handles in the tweet
                if (item in hashtags and hashtags.index(item) == 0) or (item in handles and handles.index(item) == 0):
                    selected_tweets.append(tweet)
                break
    return selected_tweets

# %%
#AUS
query =  "( #AUSvENG OR #AUSvsENG OR #australiancricket OR #CricketAustralia OR #australiacricket OR #CricketAus OR #cricketcomau OR #ENGvAUS OR #ENGvsAUS OR   #englandcricket OR #englandteam OR #EnglandCricketTeam OR #cricketengland OR #TheBarmyArmy) OR (@cricketcomau OR @CricketAus OR @englandcricket OR @TheBarmyArmy) lang:en until:1294817700 since:1294731300"
tweets = []

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    tweets.append([ tweet.date,tweet.likeCount, tweet.replyCount, tweet.retweetCount, tweet.content])
    
data  = pd.DataFrame(tweets, columns=['Date', 'likeCount','replyCount', 'retweetCount',  'Tweet' ])
data.to_csv('tweets 1.0/2011-01-12 AUSvsENG/AUS-2011-01-12.csv')

# call the dataset
data = pd.read_csv('tweets 1.0/2011-01-12 AUSvsENG/AUS-2011-01-12.csv')
# convert tweets to lowercase
data['Tweet'] = data['Tweet'].str.lower()
# remove duplicates  
df =  data.drop_duplicates(subset=['Tweet'], keep='first')
# call the function has_question_word 
sentences = df['Tweet'].to_list()
Q=[]
for sentence in sentences:
    if has_question_word(sentence):
        Q.append(sentence) 

df = df.drop(df[df['Tweet'].isin(Q)].index)
# call the function select_tweet_with_item
tweets =  df['Tweet']
list1 =  AUSvENG
I=[]
for tweet in tweets:
    if tweet not in select_tweet_with_item(tweets, list1):
        I.append(tweet) 

df = df.drop(df[df['Tweet'].isin(I)].index)

df.head()
# save the dataset
df.to_csv('tweets 2.0/2011-01-12 AUSvsENG/AUS-2011-01-12.csv')


# ENG
# call the dataset
data = pd.read_csv('tweets 1.0/2011-01-12 AUSvsENG/ENG-2011-01-12.csv')
# convert Tweets to lowercase
data['Tweet'] = data['Tweet'].str.lower()
# remove duplicates  
df =  data.drop_duplicates(subset=['Tweet'], keep='first')
# call the function has_question_word 
sentences = df['Tweet'].to_list()
Q=[]
for sentence in sentences:
    if has_question_word(sentence):
        Q.append(sentence) 

df = df.drop(df[df['Tweet'].isin(Q)].index)
# call the function select_tweet_with_item
tweets =  df['Tweet']
list1 =  ENGvAUS
I=[]
for tweet in tweets:
    if not select_tweet_with_item(tweets, list1):
        I.append(tweet) 

df = df.drop(df[df['Tweet'].isin(I)].index)

df.head()
# save the dataset
df.to_csv('tweets 2.0/2011-01-12 AUSvsENG/ENG-2011-01-12.csv')
